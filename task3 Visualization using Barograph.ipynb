# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/Users/maitrayee'

# %%
cd Downloads
# Out:
# /Users/maitrayee/Downloads

# %%
df= pd.read_csv('Iris.csv')

# %%
data1=df['Id']
df = pd.DataFrame(data)

# %%
df.plot(kind='bar')
plt.title('Bar Graph of Values')
plt.xlabel('Categories')
plt.ylabel('Id')
plt.xticks(rotation=0)  
plt.grid(axis='y')
plt.show()

# %% [markdown]
#  Hence created a bar chart to visualize the distribution of data in given dataset
